# %% [markdown]
# <a href="https://colab.research.google.com/github/mirza-ops/ShadowFox/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vaderSentiment matplotlib pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# ==========================================
# Sentiment Analysis Results Visualization
# ==========================================

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
file_path = "synthetic_sentiment_analysis_results.csv"  # Change path if needed
df = pd.read_csv(file_path)

# Display basic info
print("🔹 First 5 rows:")
print(df.head(), "\n")

print("🔹 Dataset info:")
print(df.info(), "\n")

# Check for missing values
print("🔹 Missing values per column:")
print(df.isnull().sum(), "\n")

# Drop missing or duplicate entries
df = df.dropna().drop_duplicates()

# Automatically detect sentiment column
sentiment_col = None
for col in df.columns:
    if "sentiment" in col.lower():
        sentiment_col = col
        break
if not sentiment_col:
    sentiment_col = df.columns[-1]  # fallback to last column
print(f"✅ Using sentiment column: {sentiment_col}\n")

# Sentiment distribution summary
print("🔹 Sentiment counts:")
print(df[sentiment_col].value_counts(), "\n")

# Bar chart
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x=sentiment_col)
plt.title("Sentiment Distribution")
plt.xlabel("Sentiment Category")
plt.ylabel("Count")
plt.show()

# Pie chart
plt.figure(figsize=(6, 6))
df[sentiment_col].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Sentiment Percentage Distribution")
plt.ylabel("")
plt.show()

print("🎯 Visualization complete!")
# Out:
# 🔹 First 5 rows:
#            tweet_id                                               text  \
# 0  1590000000000000  The region remains tense amid ongoing discussi...
# 1  1590000000000001        No one wins in war, only suffering spreads.
# 2  1590000000000002  Finally, some good news about humanitarian aid...
# 3  1590000000000003       Small steps toward peace are still progress.
# 4  1590000000000004  Violence continues despite international press...
#
#   sentiment Sentiment
# 0   neutral   Neutral
# 1  negative  Negative
# 2  positive  Positive
# 3  positive  Positive
# 4  negative  Negative
#
# 🔹 Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   80 non-null     int64
#  1   text       80 non-null     object
#  2   sentiment  80 non-null     object
#  3   Sentiment  80 non-null     object
# ...
